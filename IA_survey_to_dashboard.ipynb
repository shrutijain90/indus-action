# %%
from __future__ import print_function
import pickle
import os.path
from googleapiclient.discovery import build
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request
import pandas as pd
import numpy as np
import re

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# ## Obtain data from Google spreadsheet

# %%
SCOPES = ['https://www.googleapis.com/auth/spreadsheets.readonly']

if os.path.exists('token.pickle'):
    with open('token.pickle', 'rb') as token:
        creds = pickle.load(token)
        
# If there are no (valid) credentials available, let the user log in.
if not creds or not creds.valid:
    if creds and creds.expired and creds.refresh_token:
        creds.refresh(Request())
    else:
        flow = InstalledAppFlow.from_client_secrets_file(
            'credentials.json', SCOPES)
        creds = flow.run_local_server(port=0)
    # Save the credentials for the next run
    with open('token.pickle', 'wb') as token:
        pickle.dump(creds, token)

service = build('sheets', 'v4', credentials=creds)

sheet = service.spreadsheets()

# %%
def gsheet2df(gsheet):
    """ Converts Google sheet data to a Pandas DataFrame.
    Note: This script assumes that your data contains a header file on the first row!
    Also note that the Google API returns 'none' from empty cells - in order for the code
    below to work, you'll need to make sure your sheet doesn't contain empty cells,
    or update the code to account for such instances.
    """
    header = gsheet.get('values', [])[0]   # Assumes first line is header!
    values = gsheet.get('values', [])[1:]  # Everything else is data.
    if not values:
        print('No data found.')
    else:
        all_data = []
        for col_id, col_name in enumerate(header):
            column_data = []
            for row in values:
                column_data.append(row[col_id])
            ds = pd.Series(data=column_data, name=col_name)
            all_data.append(ds)
        df = pd.concat(all_data, axis=1)
        return df

# %%
spreadsheet = '1EHTQy7nnT0JWgiWenlgxbGOpTN0jvc3ZWMSYVcb3reQ'
sheet_range = '8th April 2020!A:XX'

survey_responses = sheet.values().get(spreadsheetId=spreadsheet, range=sheet_range).execute()

# %%
survey = gsheet2df(survey_responses)

# %% [markdown]
# ## Combine columns

# %%
questions = ['NameoftheDistrict', '1_1', '1_2', '2_1', '2_2', '2_3', 
             '3_1.mgnrega', '3_1.pmKisan', '3_1.ujjwala', '3_1.janDhan', '3_1.oldAgeWidow', 
             '3_1.registeredLabour', '3_1.freeRation', '3_1.notEligible', '3_1.none',
             '3_2.mgnrega', '3_2.pmKisan', '3_2.ujjwala', '3_2.janDhan', '3_2.oldAgeWidow', 
             '3_2.registeredLabour', '3_2.bplRation', '3_2.generalRation', '3_2.none',
             '3_3', '3_4', '4_1', '4_2']

for question in questions:
    cols = [col for col in survey.columns if question in col] 
    if question == 'NameoftheDistrict':
        cols = cols + ['locationBihar']
    survey[question] = survey[cols].sum(1)
    survey = survey.drop(cols, 1)

cols = ['_2' , '4_2']
survey['4_2'] = survey[cols].sum(1)
survey = survey.drop(['_2'], 1)

# %% [markdown]
# ## Clean strings

# %%
# Column names
survey = survey.rename(columns={"_id": "ID", "created": "time_created", "modified": "time_modified",
                                "introductionIam": "surveyer", 
                                "NUMBER_ID": "number_id", "introductionCallConnected": "call_connected",
                                "introductionAvailability": "availability", "locationSelectState": "state",
                                "locationNameofArea": "sub_district", "endCallStatusEndCallStatus": "end_call_status", 
                                "NameoftheDistrict": "district", "1_1": "need_meds", "1_2": "comments_health",
                                "2_1": "have_food", "2_3": "comments_food", '3_1.mgnrega': "received_mgnrega", 
                                '3_1.pmKisan': "received_pm_kisan", '3_1.ujjwala': "received_ujjwala", 
                                '3_1.janDhan': "received_jan_dhan", '3_1.oldAgeWidow': "received_old_age_widow", 
                                '3_1.registeredLabour': "received_registered_labor", 
                                '3_1.freeRation': "received_free_ration", '3_1.notEligible': "received_not_eligible", 
                                '3_1.none': "received_none", '3_2.mgnrega': "eligible_mgnrega",
                                '3_2.pmKisan': "eligible_pm_kisan", '3_2.ujjwala': "eligible_ujjwala", 
                                '3_2.janDhan': "eligible_jan_dhan", '3_2.oldAgeWidow': "eligible_old_age_widow",
                                '3_2.registeredLabour': "eligible_registered_labor", 
                                '3_2.bplRation': "eligible_bpl_ration", 
                                '3_2.generalRation': "eligible_general_ration",
                                '3_2.none': "eligible_none", "3_3": "employment_status", "3_4": "comments_benefits",
                                "4_1": "need_to_revert",
                                "4_2": "comments_additional"})

# %%
# yes / no / true / false etc

binary_cols = ['call_connected', 'availability', 'need_meds', 'have_food', 'received_mgnrega', 'received_pm_kisan', 
                'received_ujjwala', 'received_jan_dhan', 'received_old_age_widow', 'received_registered_labor', 
                'received_free_ration', 'received_not_eligible', 'received_none', 'eligible_mgnrega',
                'eligible_pm_kisan', 'eligible_ujjwala', 'eligible_jan_dhan', 'eligible_old_age_widow', 
                'eligible_registered_labor', 'eligible_bpl_ration', 'eligible_general_ration', 'eligible_none',
                'need_to_revert']

survey[binary_cols] = survey[binary_cols].replace(to_replace=r'(?i)^(yes|true)', value=True, regex=True)
survey[binary_cols] = survey[binary_cols].replace(to_replace=r'(?i)^(no|false)', value=False, regex=True)

# %%
survey['time_created'] = pd.to_datetime(survey['time_created'], format='%Y-%m-%d %I:%M %p UTC')

# %%
# date columns
survey['time_created'] = pd.to_datetime(survey['time_created'], format='%Y-%m-%d %I:%M %p UTC')
survey['time_created'] = survey['time_created'].dt.tz_localize("UTC").dt.tz_convert('Asia/Kolkata').dt.tz_localize(None)
survey['time_modified'] = pd.to_datetime(survey['time_modified'], format='%Y-%m-%d %I:%M %p UTC')
survey['time_modified'] = survey['time_modified'].dt.tz_localize("UTC").dt.tz_convert('Asia/Kolkata').dt.tz_localize(None)

# %%
# state, district, sub district
def capitalizeName(name):
    name = re.sub(r"(?i)village","", name)
    name = re.sub(r"(?<=\w)([A-Z])", r" \1", name).capitalize()
    name = name.replace("-", " ")
    name = name.strip()
    name = name.title()
    return name

survey[['state', 'district', 'sub_district']] = survey[['state', 'district', 'sub_district']].applymap(capitalizeName)

# %%
# employment status
survey['employment_status'] = survey['employment_status'].apply(lambda x: re.sub("([^\x00-\x7F])+","",x))

# %%
# NaNs
survey.replace(r'^\s*$', np.NaN, regex=True, inplace=True)
survey.dropna(axis=1, how="all", inplace=True)

# %% [markdown]
# ## Other checks

# %%
# duplicated rows
survey[survey.duplicated('ID')]
# Out:
# Empty DataFrame
# Columns: [ID, time_created, time_modified, surveyer, number_id, call_connected, availability, state, sub_district, end_call_status, district, need_meds, comments_health, have_food, comments_food, received_mgnrega, received_pm_kisan, received_ujjwala, received_jan_dhan, received_old_age_widow, received_registered_labor, received_free_ration, received_not_eligible, received_none, eligible_mgnrega, eligible_pm_kisan, eligible_ujjwala, eligible_jan_dhan, eligible_old_age_widow, eligible_registered_labor, eligible_bpl_ration, eligible_general_ration, eligible_none, employment_status, comments_benefits, need_to_revert, comments_additional]
# Index: []

# %%
# data present when call not connected or no availability
nodata_rows = survey[(survey['call_connected']==False) | (survey['availability']==False)]
nodata_rows[pd.notnull(nodata_rows[nodata_rows.columns.difference(['ID', 'time_created', 'time_modified', 'surveyer',
                                                                  'number_id', 'call_connected', 
                                                                  'availability', 'end_call_status'])]).all(axis=1)]
# Out:
#                            ID        time_created       time_modified  \
# 8    5e8dbeb3f0d65d001aac7393 2020-04-08 17:38:00 2020-04-08 17:38:00
# 218  5e8d85e3f0d65d001aac590f 2020-04-08 13:35:00 2020-04-08 13:35:00
# 336  5e8c7d1ef0d65d001aac4cee 2020-04-07 18:46:00 2020-04-07 18:46:00
# 399  5e8c6cf3f0d65d001aac469f 2020-04-07 17:37:00 2020-04-07 17:37:00
# 401  5e8c6c72f0d65d001aac4694 2020-04-07 17:35:00 2020-04-07 17:35:00
#
#                       surveyer number_id  call_connected availability  \
# 8    indusActionStaffVolunteer    510939           False          NaN
# 218  indusActionStaffVolunteer    327265            True        False
# 336  indusActionStaffVolunteer    546461           False          NaN
# 399  indusActionStaffVolunteer       NaN           False          NaN
# 401  indusActionStaffVolunteer       NaN           False          NaN
#
#              state  sub_district           end_call_status      district  \
# 8        Rajasthan           N A               wrongNumber         Ajmer
# 218   Chhattisgarh  G P Jhalmala                  callDone         Balod
# 336  Uttar Pradesh            Na                  callDone  Kanpur Nagar
# 399      Rajasthan           N A  notRespondingSwitchedOff         Ajmer
# 401      Rajasthan           N A               wrongNumber         Ajmer
#
#     need_meds                                    comments_health have_food  \
# 8       False                                                 NA      True
# 218     False  The family consist four members; it includes t...      True
# 336     False                                          No issue.      True
# 399     False                                                 NA      True
# 401     False                                                 NA      True
#
#                                          comments_food received_mgnrega  \
# 8                                                   NA            False
# 218  They having ration but to purchase vegetable a...            False
# 336                                   Sufficient food.            False
# 399                                                 NA            False
# 401                                                 NA            False
#
#     received_pm_kisan received_ujjwala received_jan_dhan  \
# 8               False            False             False
# 218             False            False             False
# 336             False             True              True
# 399             False            False             False
# 401             False            False             False
#
#     received_old_age_widow received_registered_labor received_free_ration  \
# 8                    False                     False                False
# 218                  False                     False                 True
# 336                  False                     False                 True
# 399                  False                     False                False
# 401                  False                     False                False
#
#     received_not_eligible received_none eligible_mgnrega eligible_pm_kisan  \
# 8                   False          True            False             False
# 218                 False         False             True             False
# 336                  True         False            False             False
# 399                 False          True            False             False
# 401                 False          True            False             False
#
#     eligible_ujjwala eligible_jan_dhan eligible_old_age_widow  \
# 8              False             False                  False
# 218             True              True                  False
# 336            False              True                  False
# 399            False             False                  False
# 401            False             False                  False
#
#     eligible_registered_labor eligible_bpl_ration eligible_general_ration  \
# 8                       False               False                   False
# 218                     False                True                   False
# 336                     False               False                   False
# 399                     False               False                   False
# 401                     False               False                   False
#
#     eligible_none       employment_status  \
# 8            True              unemployed
# 218         False  unemployedPostLockdown
# 336         False    employedFormalSector
# 399          True              unemployed
# 401          True              unemployed
#
#                                      comments_benefits need_to_revert  \
# 8                                                   NA          False
# 218  By professional, he is working as construction...          False
# 336                             No issue with the job.          False
# 399                                                 NA          False
# 401                                                 NA          False
#
#                                    comments_additional
# 8                                                   NA
# 218  PDS scheme is functional, government need to s...
# 336        He is doing well and take care of himself.
# 399                                                 NA
# 401                                                 NA

# %%
# call not connected but available
nodata_rows[(nodata_rows['call_connected']==False) & (nodata_rows['availability']==True)]
# Out:
# Empty DataFrame
# Columns: [ID, time_created, time_modified, surveyer, number_id, call_connected, availability, state, sub_district, end_call_status, district, need_meds, comments_health, have_food, comments_food, received_mgnrega, received_pm_kisan, received_ujjwala, received_jan_dhan, received_old_age_widow, received_registered_labor, received_free_ration, received_not_eligible, received_none, eligible_mgnrega, eligible_pm_kisan, eligible_ujjwala, eligible_jan_dhan, eligible_old_age_widow, eligible_registered_labor, eligible_bpl_ration, eligible_general_ration, eligible_none, employment_status, comments_benefits, need_to_revert, comments_additional]
# Index: []

# %%
# removing duplicates
survey.drop_duplicates(inplace=True)
survey.drop_duplicates(subset=['ID'], inplace=True)

# %%
# keeping only available
survey = survey[survey['call_connected'] == True]
survey = survey[survey['availability'] == True]

# %%
# state not entered
survey[survey['state'].isnull()]
# Out:
# Empty DataFrame
# Columns: [ID, time_created, time_modified, surveyer, number_id, call_connected, availability, state, sub_district, end_call_status, district, need_meds, comments_health, have_food, comments_food, received_mgnrega, received_pm_kisan, received_ujjwala, received_jan_dhan, received_old_age_widow, received_registered_labor, received_free_ration, received_not_eligible, received_none, eligible_mgnrega, eligible_pm_kisan, eligible_ujjwala, eligible_jan_dhan, eligible_old_age_widow, eligible_registered_labor, eligible_bpl_ration, eligible_general_ration, eligible_none, employment_status, comments_benefits, need_to_revert, comments_additional]
# Index: []

# %%
# district not entered
survey[survey['district'].isnull()]
# Out:
# Empty DataFrame
# Columns: [ID, time_created, time_modified, surveyer, number_id, call_connected, availability, state, sub_district, end_call_status, district, need_meds, comments_health, have_food, comments_food, received_mgnrega, received_pm_kisan, received_ujjwala, received_jan_dhan, received_old_age_widow, received_registered_labor, received_free_ration, received_not_eligible, received_none, eligible_mgnrega, eligible_pm_kisan, eligible_ujjwala, eligible_jan_dhan, eligible_old_age_widow, eligible_registered_labor, eligible_bpl_ration, eligible_general_ration, eligible_none, employment_status, comments_benefits, need_to_revert, comments_additional]
# Index: []

# %%
# removing rows with no state entry
survey = survey[survey['state'].notnull()]

# %%
# 3.2 not eligible true but 3.1 not eligible false
survey[(survey['eligible_none']==True) & (survey['received_not_eligible']==False)]
# Out:
#                            ID        time_created       time_modified  \
# 1    5e8dbff4f0d65d001aac73ba 2020-04-08 17:43:00 2020-04-08 17:43:00
# 3    5e8dbfa7f0d65d001aac73b1 2020-04-08 17:42:00 2020-04-08 17:42:00
# 7    5e8dbf17f0d65d001aac739e 2020-04-08 17:39:00 2020-04-08 17:39:00
# 23   5e8dbba2f0d65d001aac734d 2020-04-08 17:25:00 2020-04-08 17:25:00
# 24   5e8dbb7df0d65d001aac7349 2020-04-08 17:24:00 2020-04-08 17:24:00
# 65   5e8db388f0d65d001aac6c04 2020-04-08 16:50:00 2020-04-08 16:50:00
# 73   5e8db106f0d65d001aac6b28 2020-04-08 16:39:00 2020-04-08 16:39:00
# 75   5e8db03cf0d65d001aac6a9a 2020-04-08 16:36:00 2020-04-08 16:36:00
# 79   5e8daff6f0d65d001aac6a89 2020-04-08 16:35:00 2020-04-08 16:35:00
# 92   5e8dad30f0d65d001aac6a2c 2020-04-08 16:23:00 2020-04-08 16:23:00
# 93   5e8dad25f0d65d001aac6a28 2020-04-08 16:23:00 2020-04-08 16:23:00
# 94   5e8dad13f0d65d001aac6a24 2020-04-08 16:23:00 2020-04-08 16:23:00
# 100  5e8dab9cf0d65d001aac6a08 2020-04-08 16:16:00 2020-04-08 16:16:00
# 102  5e8dab53f0d65d001aac69ff 2020-04-08 16:15:00 2020-04-08 16:15:00
# 107  5e8daa76f0d65d001aac69eb 2020-04-08 16:11:00 2020-04-08 16:11:00
# 119  5e8da7e4f0d65d001aac6853 2020-04-08 16:01:00 2020-04-08 16:01:00
# 157  5e8da151f0d65d001aac65ff 2020-04-08 15:32:00 2020-04-08 15:32:00
# 163  5e8d9e0ef0d65d001aac63b5 2020-04-08 15:19:00 2020-04-08 15:19:00
# 180  5e8d96cff0d65d001aac5d57 2020-04-08 14:48:00 2020-04-08 14:48:00
# 206  5e8d8b59f0d65d001aac5a0c 2020-04-08 13:59:00 2020-04-08 13:59:00
# 208  5e8d8932f0d65d001aac59d2 2020-04-08 13:50:00 2020-04-08 13:50:00
# 210  5e8d88c1f0d65d001aac59c9 2020-04-08 13:48:00 2020-04-08 13:48:00
# 216  5e8d8713f0d65d001aac5919 2020-04-08 13:40:00 2020-04-08 13:40:00
# 223  5e8d8382f0d65d001aac58fa 2020-04-08 13:25:00 2020-04-08 13:25:00
# 225  5e8d8343f0d65d001aac58f2 2020-04-08 13:24:00 2020-04-08 13:24:00
# 237  5e8d7f8df0d65d001aac5811 2020-04-08 13:08:00 2020-04-08 13:08:00
# 261  5e8d6fd4f0d65d001aac5711 2020-04-08 12:01:00 2020-04-08 12:01:00
# 262  5e8d6f1ff0d65d001aac570c 2020-04-08 11:58:00 2020-04-08 11:58:00
# 268  5e8d6b62f0d65d001aac5632 2020-04-08 11:42:00 2020-04-08 11:42:00
# 293  5e8d5d86f0d65d001aac53a4 2020-04-08 10:43:00 2020-04-08 10:43:00
# 295  5e8d5bd5f0d65d001aac537f 2020-04-08 10:36:00 2020-04-08 10:36:00
# 314  5e8c8561f0d65d001aac4d55 2020-04-07 19:21:00 2020-04-07 19:21:00
# 318  5e8c83e5f0d65d001aac4d3c 2020-04-07 19:15:00 2020-04-07 19:15:00
# 320  5e8c8350f0d65d001aac4d34 2020-04-07 19:12:00 2020-04-07 19:12:00
# 321  5e8c8229f0d65d001aac4d30 2020-04-07 19:07:00 2020-04-07 19:07:00
# 326  5e8c80bbf0d65d001aac4d1c 2020-04-07 19:01:00 2020-04-07 19:01:00
# 335  5e8c7d2ef0d65d001aac4cf2 2020-04-07 18:46:00 2020-04-07 18:46:00
# 349  5e8c7969f0d65d001aac4cb8 2020-04-07 18:30:00 2020-04-07 18:30:00
# 383  5e8c6f29f0d65d001aac46e9 2020-04-07 17:46:00 2020-04-07 17:46:00
# 387  5e8c6edef0d65d001aac46d7 2020-04-07 17:45:00 2020-04-07 17:45:00
# 394  5e8c6df3f0d65d001aac46b9 2020-04-07 17:41:00 2020-04-07 17:41:00
# 402  5e8c6c64f0d65d001aac4690 2020-04-07 17:34:00 2020-04-07 17:34:00
# 406  5e8c6b91f0d65d001aac467c 2020-04-07 17:31:00 2020-04-07 17:31:00
# 408  5e8c6b06f0d65d001aac4673 2020-04-07 17:29:00 2020-04-07 17:29:00
# 415  5e8c695cf0d65d001aac464b 2020-04-07 17:21:00 2020-04-07 17:21:00
# 423  5e8c65b6f0d65d001aac42c6 2020-04-07 17:06:00 2020-04-07 17:06:00
# 424  5e8c659cf0d65d001aac42c2 2020-04-07 17:05:00 2020-04-07 17:05:00
# 427  5e8c6520f0d65d001aac42b2 2020-04-07 17:03:00 2020-04-07 17:03:00
# 458  5e8c6030f0d65d001aac417f 2020-04-07 16:42:00 2020-04-07 16:42:00
# 484  5e8c57cef0d65d001aac402e 2020-04-07 16:07:00 2020-04-07 16:07:00
# 501  5e8c53dbf0d65d001aac3e4f 2020-04-07 15:50:00 2020-04-07 15:50:00
# 543  5e8c4ab3f0d65d001aac37eb 2020-04-07 15:11:00 2020-04-07 15:11:00
# 566  5e8c4594f0d65d001aac32b3 2020-04-07 14:49:00 2020-04-07 14:49:00
# 574  5e8c43d6f0d65d001aac2c2e 2020-04-07 14:41:00 2020-04-07 14:41:00
# 581  5e8c40bcf0d65d001aac2486 2020-04-07 14:28:00 2020-04-07 14:28:00
# 595  5e8c3825f0d65d001aac2165 2020-04-07 13:51:00 2020-04-07 13:51:00
# 597  5e8c368cf0d65d001aac1f7a 2020-04-07 13:45:00 2020-04-07 13:45:00
# 614  5e8c2d8af0d65d001aac181a 2020-04-07 13:06:00 2020-04-07 13:06:00
# 626  5e8c2822f0d65d001aac15c6 2020-04-07 12:43:00 2020-04-07 12:43:00
# 639  5e8c23c0f0d65d001aac1237 2020-04-07 12:24:00 2020-04-07 12:24:00
# 642  5e8c22def0d65d001aac1178 2020-04-07 12:21:00 2020-04-07 12:21:00
# 644  5e8c21c9f0d65d001aac116d 2020-04-07 12:16:00 2020-04-07 12:16:00
# 651  5e8c203ff0d65d001aac1150 2020-04-07 12:09:00 2020-04-07 12:09:00
# 654  5e8c1e6ff0d65d001aac0e07 2020-04-07 12:02:00 2020-04-07 12:02:00
# 656  5e8c1d2df0d65d001aac0d84 2020-04-07 11:56:00 2020-04-07 11:56:00
# 658  5e8c192cf0d65d001aac0d35 2020-04-07 11:39:00 2020-04-07 11:39:00
# 669  5e8c0875f0d65d001aac0ab2 2020-04-07 10:28:00 2020-04-07 10:28:00
# 698  5e8b467bf0d65d001aac0537 2020-04-06 20:40:00 2020-04-06 20:40:00
# 709  5e8b349cf0d65d001aac03f2 2020-04-06 19:24:00 2020-04-06 19:24:00
# 724  5e8b288df0d65d001aabff56 2020-04-06 18:33:00 2020-04-06 18:33:00
# 725  5e8b286ff0d65d001aabff51 2020-04-06 18:32:00 2020-04-06 18:32:00
# 731  5e8b23cdf0d65d001aabfb77 2020-04-06 18:12:00 2020-04-06 18:12:00
# 732  5e8b237ef0d65d001aabfb73 2020-04-06 18:11:00 2020-04-06 18:11:00
# 733  5e8b2352f0d65d001aabfb6e 2020-04-06 18:10:00 2020-04-06 18:10:00
# 751  5e8b18d1f0d65d001aabf85d 2020-04-06 17:26:00 2020-04-06 17:26:00
# 755  5e8b178ef0d65d001aabf6eb 2020-04-06 17:20:00 2020-04-06 17:20:00
# 766  5e8b141bf0d65d001aabf52e 2020-04-06 17:05:00 2020-04-06 17:05:00
# 781  5e8b1160f0d65d001aabf4e5 2020-04-06 16:54:00 2020-04-06 16:54:00
#
#                                 surveyer number_id  call_connected  \
# 1              indusActionStaffVolunteer    370921            True
# 3              indusActionStaffVolunteer    753355            True
# 7              indusActionStaffVolunteer    362007            True
# 23             indusActionStaffVolunteer    373701            True
# 24             indusActionStaffVolunteer    857808            True
# 65             indusActionStaffVolunteer    224916            True
# 73             indusActionStaffVolunteer    604257            True
# 75             indusActionStaffVolunteer    156313            True
# 79             indusActionStaffVolunteer    401683            True
# 92   solveNinjaReapBenefitStaffVolunteer    833573            True
# 93             indusActionStaffVolunteer    552312            True
# 94             indusActionStaffVolunteer    604257            True
# 100            indusActionStaffVolunteer    774263            True
# 102            indusActionStaffVolunteer    601640            True
# 107            indusActionStaffVolunteer    659303            True
# 119            indusActionStaffVolunteer    889293            True
# 157            indusActionStaffVolunteer    750764            True
# 163            indusActionStaffVolunteer    371482            True
# 180            indusActionStaffVolunteer    227147            True
# 206            indusActionStaffVolunteer    472036            True
# 208            indusActionStaffVolunteer    167354            True
# 210            indusActionStaffVolunteer    137291            True
# 216            indusActionStaffVolunteer    209152            True
# 223            indusActionStaffVolunteer    566154            True
# 225            indusActionStaffVolunteer    299312            True
# 237            indusActionStaffVolunteer    641245            True
# 261            indusActionStaffVolunteer    465154            True
# 262            indusActionStaffVolunteer    506561            True
# 268            indusActionStaffVolunteer    504151            True
# 293            indusActionStaffVolunteer    472657            True
# 295            indusActionStaffVolunteer    501318            True
# 314            indusActionStaffVolunteer    270090            True
# 318            indusActionStaffVolunteer    319120            True
# 320            indusActionStaffVolunteer    836660            True
# 321            indusActionStaffVolunteer    403316            True
# 326            indusActionStaffVolunteer    344830            True
# 335            indusActionStaffVolunteer    216495            True
# 349            indusActionStaffVolunteer    501218            True
# 383            indusActionStaffVolunteer       NaN            True
# 387            indusActionStaffVolunteer       NaN            True
# 394            indusActionStaffVolunteer       NaN            True
# 402            indusActionStaffVolunteer       NaN            True
# 406            indusActionStaffVolunteer       NaN            True
# 408            indusActionStaffVolunteer       NaN            True
# 415            indusActionStaffVolunteer       NaN            True
# 423            indusActionStaffVolunteer       NaN            True
# 424            indusActionStaffVolunteer       NaN            True
# 427            indusActionStaffVolunteer       NaN            True
# 458            indusActionStaffVolunteer    915304            True
# 484            indusActionStaffVolunteer    155544            True
# 501            indusActionStaffVolunteer    544883            True
# 543  solveNinjaReapBenefitStaffVolunteer    683794            True
# 566            indusActionStaffVolunteer    354182            True
# 574            indusActionStaffVolunteer    838746            True
# 581            indusActionStaffVolunteer    951270            True
# 595            indusActionStaffVolunteer    718508            True
# 597             teachForIndiaFellowStaff    810459            True
# 614            indusActionStaffVolunteer    708573            True
# 626            indusActionStaffVolunteer    636520            True
# 639            indusActionStaffVolunteer    900359            True
# 642            indusActionStaffVolunteer    748236            True
# 644            indusActionStaffVolunteer    752062            True
# 651            indusActionStaffVolunteer    247623            True
# 654            indusActionStaffVolunteer    503177            True
# 656            indusActionStaffVolunteer    783788            True
# 658            indusActionStaffVolunteer    995786            True
# 669            indusActionStaffVolunteer    483632            True
# 698            indusActionStaffVolunteer    721374            True
# 709            indusActionStaffVolunteer    166843            True
# 724            indusActionStaffVolunteer    178724            True
# 725            indusActionStaffVolunteer    760106            True
# 731            indusActionStaffVolunteer    280459            True
# 732            indusActionStaffVolunteer    904025            True
# 733            indusActionStaffVolunteer    755458            True
# 751            indusActionStaffVolunteer    122829            True
# 755            indusActionStaffVolunteer    227257            True
# 766            indusActionStaffVolunteer    461309            True
# 781            indusActionStaffVolunteer    613632            True
#
#     availability           state  \
# 1           True       Rajasthan
# 3           True   Uttar Pradesh
# 7           True           Delhi
# 23          True           Bihar
# 24          True   Uttar Pradesh
# 65          True       Rajasthan
# 73          True     Maharashtra
# 75          True   Uttar Pradesh
# 79          True       Rajasthan
# 92          True    Chhattisgarh
# 93          True     Maharashtra
# 94          True     Maharashtra
# 100         True       Rajasthan
# 102         True       Rajasthan
# 107         True  Madhya Pradesh
# 119         True       Rajasthan
# 157         True     Maharashtra
# 163         True     Maharashtra
# 180         True     Maharashtra
# 206         True           Delhi
# 208         True     Maharashtra
# 210         True     Maharashtra
# 216         True         Gujarat
# 223         True         Gujarat
# 225         True     Maharashtra
# 237         True  Madhya Pradesh
# 261         True         Gujarat
# 262         True           Bihar
# 268         True     Maharashtra
# 293         True         Gujarat
# 295         True       Telangana
# 314         True       Karnataka
# 318         True       Karnataka
# 320         True       Karnataka
# 321         True   Uttar Pradesh
# 326         True   Uttar Pradesh
# 335         True       Karnataka
# 349         True         Gujarat
# 383         True       Rajasthan
# 387         True     Maharashtra
# 394         True       Telangana
# 402         True       Telangana
# 406         True   Uttar Pradesh
# 408         True       Rajasthan
# 415         True       Rajasthan
# 423         True   Uttar Pradesh
# 424         True     Maharashtra
# 427         True       Telangana
# 458         True     Maharashtra
# 484         True         Gujarat
# 501         True       Rajasthan
# 543         True    Chhattisgarh
# 566         True       Telangana
# 574         True           Bihar
# 581         True       Rajasthan
# 595         True     Maharashtra
# 597         True       Rajasthan
# 614         True           Delhi
# 626         True         Gujarat
# 639         True         Gujarat
# 642         True         Gujarat
# 644         True         Gujarat
# 651         True         Gujarat
# 654         True         Gujarat
# 656         True         Gujarat
# 658         True         Gujarat
# 669         True         Gujarat
# 698         True  Madhya Pradesh
# 709         True       Karnataka
# 724         True       Karnataka
# 725         True       Rajasthan
# 731         True       Telangana
# 732         True   Uttar Pradesh
# 733         True  Madhya Pradesh
# 751         True   Uttar Pradesh
# 755         True    Chhattisgarh
# 766         True  Madhya Pradesh
# 781         True  Madhya Pradesh
#
#                                           sub_district    end_call_status  \
# 1                                                  N A           callDone
# 3                                          Naini A D A           callDone
# 7                                        Not Specified           callDone
# 23                                             Chhapra           callDone
# 24                                           Kalyanpur           callDone
# 65                                                 N A           callDone
# 73                                             Govandi           callDone
# 75                                                 N A           callDone
# 79                                                 N A           callDone
# 92                                             Sakhara           callDone
# 93                                             Govandi           callDone
# 94   Did Not Get This Information As The Person I S...           callDone
# 100                                                N A           callDone
# 102                                                N A           callDone
# 107                                            Thencha  callAgainFollowUp
# 119                                      Shastri Nagar           callDone
# 157                                               Pune           callDone
# 163                                           Goregaon           callDone
# 180                                           Kharghar           callDone
# 206                                   Dwaraka Sector 8           callDone
# 208                                            Manjiri           callDone
# 210                                             Kalyan           callDone
# 216                                           Vadodara           callDone
# 223                                             Anklav     incompleteCall
# 225                                         Ulhasnagar           callDone
# 237                                     Aero Drum Road           callDone
# 261                                      Parwat Patiya           callDone
# 262                                             Jhajha  callAgainFollowUp
# 268                                            Dahisar           callDone
# 293                                             Lambha           callDone
# 295                              Uppaguda N R I Colony  callAgainFollowUp
# 314                                             Madoor           callDone
# 318                                              Hosur           callDone
# 320                                          Shakangar           callDone
# 321                                           Harnatha           callDone
# 326                                         Goaltowli.           callDone
# 335                                    Padmanabhanagar           callDone
# 349                                       Ranjit Nagar           callDone
# 383                                                N A           callDone
# 387                                              Vashi           callDone
# 394                                     Sai Baba Nagar           callDone
# 402                                         Dammaiguda           callDone
# 406                                       Shahadatganj           callDone
# 408                                        Mangam City           callDone
# 415                                          Pepalkeda           callDone
# 423                                C H I T R A K O O T           callDone
# 424                                             Pimpri           callDone
# 427                                      Sai Ram Nagar           callDone
# 458                              Sanatacruz, Bus Stand  callAgainFollowUp
# 484                                            Kalupur           callDone
# 501                          S H A S H T R I N A A G R           callDone
# 543                                         Bhakurbhat           callDone
# 566                        Yellareddyguda, Malkajigiri           callDone
# 574                                              Barwa           callDone
# 581                                         Tara Nagar           callDone
# 595                                              Thane           callDone
# 597                                       Adarsh Nagar           callDone
# 614                                           Badarpur           callDone
# 626            Karat Road, Taluka Jalot, Limbdi, Dahod  callAgainFollowUp
# 639                                         Gulabnagar           callDone
# 642                                          Gitanagar           callDone
# 644                                 Naroda, Laxminagar           callDone
# 651                                           Haripura           callDone
# 654                                            Chiroda           callDone
# 656                                    Alidar, Kodinar           callDone
# 658                                               Vadi           callDone
# 669                                          Bapunagar           callDone
# 698                                                A A           callDone
# 709                                           Hulimavu           callDone
# 724                                                N/A           callDone
# 725                                                N A           callDone
# 731                                           Madhapur  callAgainFollowUp
# 732                                          Hardoiyya  callAgainFollowUp
# 733                                             Baroli           callDone
# 751                                       Didn'T Share           callDone
# 755                                   Did Not Disclose           callDone
# 766                                      Choti Bhumori           callDone
# 781                                      Gransahu Jadi  callAgainFollowUp
#
#              district need_meds  \
# 1              Jaipur     False
# 3           Prayagraj     False
# 7          East Delhi      True
# 23              Saran      True
# 24            Lucknow     False
# 65             Jaipur     False
# 73              Akola     False
# 75             Shamli     False
# 79           Bhilwara     False
# 92              Balod     False
# 93    Mumbai Suburban     False
# 94              Akola     False
# 100            Jaipur     False
# 102            Jalore     False
# 107           Barwani      True
# 119            Jaipur     False
# 157              Pune     False
# 163             Akola     False
# 180   Mumbai Suburban     False
# 206  South West Delhi      True
# 208              Pune      True
# 210             Akola     False
# 216          Vadodara     False
# 223             Anand     False
# 225   Mumbai Suburban     False
# 237            Indore     False
# 261             Surat     False
# 262         Madhubani     False
# 268             Thane     False
# 293         Ahmedabad     False
# 295        Sangareddy     False
# 314          Dakshina     False
# 318   Bangalore Rural     False
# 320   Bangalore Rural     False
# 321            Amethi     False
# 326      Kanpur Dehat     False
# 335   Bangalore Urban     False
# 349          Jamnagar     False
# 383            Jaipur     False
# 387   Mumbai Suburban     False
# 394         Hyderabad     False
# 402           Medchal     False
# 406           Lucknow     False
# 408            Jaipur      True
# 415         Bharatpur     False
# 423        Chitrakoot     False
# 424              Pune     False
# 427         Hyderabad     False
# 458       Mumbai City     False
# 484         Ahmedabad     False
# 501            Jaipur     False
# 543             Balod     False
# 566         Hyderabad     False
# 574             Siwan     False
# 581             Churu     False
# 595             Thane      True
# 597            Jaipur      True
# 614       South Delhi     False
# 626             Dahod     False
# 639          Jamnagar     False
# 642         Ahmedabad     False
# 644         Ahmedabad     False
# 651             Surat     False
# 654       Gandhinagar     False
# 656       Gir Somnath     False
# 658          Vadodara     False
# 669         Ahmedabad     False
# 698            Bhopal     False
# 709   Bangalore Urban     False
# 724   Bangalore Rural     False
# 725             Ajmer     False
# 731         Hyderabad      True
# 732           Sitapur     False
# 733            Indore     False
# 751           Sambhal     False
# 755            Raipur     False
# 766            Indore     False
# 781            Indore     False
#
#                                        comments_health have_food  \
# 1                                             No need       True
# 3                              currently no any issue       True
# 7    A member requires a medical attention but the ...      True
# 23                                                  NA      True
# 24                    swasth sambdhi koi samsya ni hai     False
# 65                                        No comments       True
# 73   He said that they are not in need of health se...      True
# 75                                                  NA      True
# 79                                                  NA     False
# 92                                                 Nil      True
# 93                                                Fine     False
# 94                  Everything is sufficient as of now      True
# 100                                       Not required      True
# 102                                                 NA      True
# 107  A kid in the house has TB. Will have to check ...      True
# 119                                                 NA     False
# 157                                               Fine      True
# 163  Ram said that the situation is stable as of no...      True
# 180                                        everyone ok      True
# 206                                          No issues      True
# 208  His son has a cough since 8 days , he has visi...      True
# 210  He said that he doesn't need any help in this ...      True
# 216                                                 NA      True
# 223                                                 NA      True
# 225                               all fine health wise     False
# 237                                           No need.     False
# 261                                                 NA     False
# 262                         Medicine is not an issue.      False
# 268                          They did not need support     False
# 293                                                 NA      True
# 295                                           ఏం లేదు       True
# 314                                               None      True
# 318                                               None     False
# 320                                               none     False
# 321                                            No need      True
# 326                                   No medical need.     False
# 335                                                 No      True
# 349                                      Not required       True
# 383  NA\nNormal fever- has given medicine to the pe...      True
# 387                                             all ok     False
# 394                                               None     False
# 402                                               none      True
# 406                                koi samsya nahi hai      True
# 408                                           All well      True
# 415                                           all good      True
# 423                                                 NA      True
# 424        Everyone is safe. Nothing to be worry about     False
# 427                                              none.      True
# 458                                                 No     False
# 484                                                  -      True
# 501                                NOT REQUIREMENT NOW      True
# 543                                                N/A      True
# 566  Using medicine which is available near by medi...     False
# 574  Mom have pain in leg and her 4 days medicine i...      True
# 581                                        No comments      True
# 595                                         All fine.       True
# 597                          15 people in the family.      False
# 614                                                 No     False
# 626                            Medicines are available      True
# 639  No food/medicine related problems in the house...      True
# 642                                                 NA      True
# 644                                                 NA     False
# 651                                     No requirement      True
# 654                                                 NA      True
# 656                                                 Na     False
# 658                                Temporary Available     False
# 669                                                 NA      True
# 698                                               none     False
# 709                                                 no      True
# 724  The speaker was reluctant to share information...      True
# 725                                                 NA      True
# 731                                                 Na      True
# 732                                koi dikkat nahi hai     False
# 733                                               none     False
# 751                                        No comments      True
# 755                                                 NA     False
# 766                                                  .     False
# 781                                               none      True
#
#                                          comments_food received_mgnrega  \
# 1                                              No need            False
# 3                          filhal koi samsya ni hai .             False
# 7                                                   NA            False
# 23                                                  NA            False
# 24   bijli ka chota mota kaam krte the lock down ke...            False
# 65                                         No comments            False
# 73   Izhar said that although he and his wife are c...            False
# 75                                                  NA            False
# 79                           2-4 days food available,             False
# 92                                                 Nil            False
# 93                 Need food. Don't have ration card.             False
# 94                  Everything is sufficient as of now            False
# 100                                   have sufficient             False
# 102                                                 NA            False
# 107  Has food for now. Has ration card too. Gave hi...            False
# 119                                                 NA            False
# 157                                                Yes            False
# 163  Ram said that while they have enough food for ...            False
# 180                                       currently ok            False
# 206                                          No issues            False
# 208                  Works in mall, no problem of food            False
# 210  He emphasized that his food needs are being me...            False
# 216                                                 NA            False
# 223                                                 NA            False
# 225  Person is a carpenter, without ration card. Ra...            False
# 237    Have food available. Shared the helpline number            False
# 261  Tushar Patel,\n303, Sitapalace Apartment, Gane...            False
# 262                Food, gas and money are a big issue            False
# 268                          They did not need support            False
# 293  Kalpesh Chakravati\n13, Meeranagar, Near Indir...            False
# 295                                            ఎం లేదు            False
# 314                                               none            False
# 318                                               None            False
# 320                                               none            False
# 321                               Bought their ration             False
# 326                                      Needs ration.            False
# 335                                       No problem!             False
# 349                                      Not required             False
# 383                                                 NA            False
# 387                                      low on ration            False
# 394  They have rice but they do not have dal, salt ...            False
# 402                                               none            False
# 406                    paryapt bhojan ki vyvstha hai .            False
# 408          They distribute 200 packets of food daily            False
# 415  Has enough food at home; helps out others as well            False
# 423                                                 NA            False
# 424                                         Sufficient            False
# 427                                              none.            False
# 458  No food to eat. No government food has been re...            False
# 484  Has enough food to last a few days. He said he...            False
# 501                                NOT REQUIREMENT NOW            False
# 543                                                N/A            False
# 566  They were labour construction worker, migrated...            False
# 574         Have sufficient food to survive till 15th.            False
# 581                                        No comments            False
# 595                                         All fine.             False
# 597  Kirana shops are not open so can't get materia...            False
# 614                                                 No            False
# 626  His family is not facing any problem but he sa...            False
# 639  No food/medicine related problems in the house...            False
# 642                                                 NA            False
# 644                          No Ration in kirana store            False
# 651  No one in the area is facing any food/medicine...            False
# 654                                                 NA            False
# 656              APL card in process needs to collect.            False
# 658  Need food as the beneficiary is having food fo...            False
# 669                                          Need Food            False
# 698  children also in the family. numbers shared wi...            False
# 709  no help government offered. Because we are Bra...            False
# 724  The speaker was reluctant to share information...            False
# 725                                                 NA            False
# 731                                                 Na            False
# 732                               koi dikkat nahi hai             False
# 733                                               none            False
# 751                                                 NA            False
# 755                                                 NA            False
# 766  gets food from mothers house, stays with her k...            False
# 781                                               none            False
#
#     received_pm_kisan received_ujjwala received_jan_dhan  \
# 1               False            False             False
# 3               False            False             False
# 7               False            False             False
# 23              False            False             False
# 24              False            False             False
# 65              False            False             False
# 73              False            False             False
# 75              False            False             False
# 79              False            False             False
# 92              False            False             False
# 93              False            False             False
# 94              False            False             False
# 100             False            False             False
# 102             False            False             False
# 107             False            False             False
# 119             False             True              True
# 157             False            False             False
# 163             False            False             False
# 180             False            False             False
# 206             False            False             False
# 208             False            False             False
# 210             False            False             False
# 216             False            False             False
# 223             False            False             False
# 225             False            False             False
# 237             False            False             False
# 261             False            False             False
# 262             False            False             False
# 268             False            False             False
# 293             False            False             False
# 295             False            False             False
# 314             False            False             False
# 318             False            False             False
# 320             False             True             False
# 321             False             True              True
# 326             False             True              True
# 335             False            False             False
# 349             False            False             False
# 383             False            False             False
# 387             False            False             False
# 394             False            False             False
# 402             False            False             False
# 406             False            False             False
# 408             False            False             False
# 415             False            False             False
# 423             False            False             False
# 424             False            False             False
# 427             False            False             False
# 458             False            False             False
# 484             False            False             False
# 501             False            False             False
# 543             False            False             False
# 566             False            False             False
# 574             False            False             False
# 581             False            False             False
# 595             False            False             False
# 597             False            False             False
# 614             False            False             False
# 626             False            False             False
# 639             False            False             False
# 642             False            False             False
# 644             False            False             False
# 651             False            False             False
# 654             False            False             False
# 656             False            False             False
# 658             False            False             False
# 669             False            False             False
# 698             False            False             False
# 709             False            False             False
# 724             False            False             False
# 725             False            False             False
# 731             False            False             False
# 732             False            False             False
# 733             False            False             False
# 751             False            False             False
# 755             False            False             False
# 766             False            False             False
# 781             False            False             False
#
#     received_old_age_widow received_registered_labor received_free_ration  \
# 1                    False                     False                False
# 3                    False                     False                False
# 7                    False                     False                False
# 23                   False                     False                False
# 24                   False                     False                False
# 65                   False                     False                False
# 73                   False                     False                False
# 75                   False                     False                False
# 79                   False                     False                False
# 92                   False                     False                False
# 93                   False                     False                False
# 94                   False                     False                False
# 100                  False                     False                False
# 102                  False                     False                False
# 107                  False                     False                False
# 119                  False                     False                 True
# 157                  False                     False                False
# 163                  False                     False                False
# 180                  False                     False                False
# 206                  False                     False                False
# 208                  False                     False                False
# 210                  False                     False                False
# 216                  False                     False                False
# 223                  False                     False                False
# 225                  False                     False                False
# 237                  False                     False                False
# 261                  False                     False                False
# 262                  False                     False                False
# 268                  False                     False                False
# 293                  False                     False                False
# 295                  False                     False                 True
# 314                  False                     False                False
# 318                  False                     False                False
# 320                  False                     False                False
# 321                  False                     False                 True
# 326                  False                     False                False
# 335                  False                     False                False
# 349                  False                     False                False
# 383                  False                     False                False
# 387                  False                     False                False
# 394                  False                     False                False
# 402                  False                     False                False
# 406                  False                     False                False
# 408                  False                     False                False
# 415                  False                     False                False
# 423                  False                     False                False
# 424                  False                     False                False
# 427                  False                     False                False
# 458                  False                     False                False
# 484                  False                     False                False
# 501                  False                     False                False
# 543                  False                     False                False
# 566                  False                      True                 True
# 574                  False                     False                False
# 581                  False                     False                False
# 595                  False                     False                False
# 597                  False                     False                False
# 614                  False                     False                False
# 626                  False                     False                False
# 639                  False                     False                False
# 642                  False                     False                False
# 644                  False                     False                False
# 651                  False                     False                False
# 654                  False                     False                False
# 656                  False                     False                False
# 658                  False                     False                False
# 669                  False                     False                False
# 698                  False                     False                False
# 709                  False                     False                False
# 724                  False                     False                False
# 725                  False                     False                False
# 731                  False                     False                False
# 732                  False                     False                False
# 733                  False                     False                False
# 751                  False                     False                False
# 755                  False                     False                False
# 766                  False                     False                False
# 781                  False                     False                False
#
#     received_not_eligible received_none eligible_mgnrega eligible_pm_kisan  \
# 1                   False          True            False             False
# 3                   False          True            False             False
# 7                   False          True            False             False
# 23                  False          True            False             False
# 24                  False          True            False             False
# 65                  False          True            False             False
# 73                  False          True            False             False
# 75                  False          True            False             False
# 79                  False          True            False             False
# 92                  False          True            False             False
# 93                  False          True            False             False
# 94                  False          True            False             False
# 100                 False          True            False             False
# 102                 False          True            False             False
# 107                 False          True            False             False
# 119                 False         False            False             False
# 157                 False          True            False             False
# 163                 False          True            False             False
# 180                 False          True            False             False
# 206                 False          True            False             False
# 208                 False          True            False             False
# 210                 False          True            False             False
# 216                 False          True            False             False
# 223                 False          True            False             False
# 225                 False          True            False             False
# 237                 False          True            False             False
# 261                 False          True            False             False
# 262                 False          True            False             False
# 268                 False          True            False             False
# 293                 False          True            False             False
# 295                 False         False            False             False
# 314                 False          True            False             False
# 318                 False          True            False             False
# 320                 False          True            False             False
# 321                 False         False            False             False
# ...
# 501                     False               False                   False
# 543                     False               False                   False
# 566                     False               False                   False
# 574                     False               False                   False
# 581                     False               False                   False
# 595                     False               False                   False
# 597                     False               False                   False
# 614                     False               False                   False
# 626                     False               False                   False
# 639                     False               False                   False
# 642                     False               False                   False
# 644                     False               False                   False
# 651                     False               False                   False
# 654                     False               False                   False
# 656                     False               False                   False
# 658                     False               False                   False
# 669                     False               False                   False
# 698                     False               False                   False
# 709                     False               False                   False
# 724                     False               False                   False
# 725                     False               False                   False
# 731                     False               False                   False
# 732                     False               False                   False
# 733                     False               False                   False
# 751                     False               False                   False
# 755                     False               False                   False
# 766                     False               False                   False
# 781                     False               False                   False
#
#     eligible_none       employment_status  \
# 1            True              unemployed
# 3            True  unemployedPostLockdown
# 7            True              unemployed
# 23           True    employedFormalSector
# 24           True  unemployedPostLockdown
# 65           True  employedInformalSector
# 73           True  unemployedPostLockdown
# 75           True              unemployed
# 79           True  unemployedPostLockdown
# 92           True              unemployed
# 93           True  employedInformalSector
# 94           True    employedFormalSector
# 100          True    employedFormalSector
# 102          True              unemployed
# 107          True  unemployedPostLockdown
# 119          True    employedFormalSector
# 157          True  employedInformalSector
# 163          True    employedFormalSector
# 180          True  unemployedPostLockdown
# 206          True    employedFormalSector
# 208          True    employedFormalSector
# 210          True  unemployedPostLockdown
# 216          True  employedInformalSector
# 223          True  employedInformalSector
# 225          True  employedInformalSector
# 237          True  employedInformalSector
# 261          True    employedFormalSector
# 262          True  unemployedPostLockdown
# 268          True  employedInformalSector
# 293          True  employedInformalSector
# 295          True              unemployed
# 314          True  employedInformalSector
# 318          True  employedInformalSector
# 320          True  unemployedPostLockdown
# 321          True  employedInformalSector
# 326          True  employedInformalSector
# 335          True    employedFormalSector
# 349          True    employedFormalSector
# 383          True  employedInformalSector
# 387          True  unemployedPostLockdown
# 394          True  unemployedPostLockdown
# 402          True    employedFormalSector
# 406          True    employedFormalSector
# 408          True  employedInformalSector
# 415          True  employedInformalSector
# 423          True  unemployedPostLockdown
# 424          True  employedInformalSector
# 427          True              unemployed
# 458          True  employedInformalSector
# 484          True  unemployedPostLockdown
# 501          True              unemployed
# 543          True  unemployedPostLockdown
# 566          True  employedInformalSector
# 574          True  employedInformalSector
# 581          True              unemployed
# 595          True    employedFormalSector
# 597          True    employedFormalSector
# 614          True    employedFormalSector
# 626          True  unemployedPostLockdown
# 639          True  unemployedPostLockdown
# 642          True    employedFormalSector
# 644          True    employedFormalSector
# 651          True  unemployedPostLockdown
# 654          True  employedInformalSector
# 656          True  employedInformalSector
# 658          True  employedInformalSector
# 669          True  employedInformalSector
# 698          True  unemployedPostLockdown
# 709          True    employedFormalSector
# 724          True  employedInformalSector
# 725          True              unemployed
# 731          True  unemployedPostLockdown
# 732          True  employedInformalSector
# 733          True  unemployedPostLockdown
# 751          True    employedFormalSector
# 755          True  employedInformalSector
# 766          True              unemployed
# 781          True    employedFormalSector
#
#                                      comments_benefits need_to_revert  \
# 1                                                   NA          False
# 3    banaras ke rehne wale hain .3 saal pehle prayg...          False
# 7                                                   NA          False
# 23                                                  NA          False
# 24   inke pas ration card nahi hai .inke pita ji ka...          False
# 65                                         No comments          False
# 73   He said that there are many in his area who ar...           True
# 75                                         No comments           True
# 79   If there was a survey before the lock-down it ...          False
# 92                                                 Nil          False
# 93         Have adhaar card but could not get ration.           False
# 94   Sivam said that he has friends Who are stuck i...           True
# 100  this family do not required any support from G...          False
# 102                                        No comments          False
# 107                                                NA            True
# 119                                                 NA          False
# 157                                               None          False
# 163  Also provided him with state helpline numbers ...          False
# 180                                             driver          False
# 206  The breadwinner is a CRPF soldier hence they d...           True
# 208                            Ration card in village.          False
# 210  Although he is unemployed he denied needing he...          False
# 216                                                 NA          False
# 223                                                 NA          False
# 225  Informed regarding rent that does not need to ...           True
# 237          Employed but will not receive the salary.          False
# 261  Tushar Patel,\n303, Sitapalace Apartment, Gane...          False
# 262  Vikas is a migrant worker who went back to bih...           True
# 268    Rima said that they have sufficient resources.           False
# 293  Kalpesh Chakravati\n13, Meeranagar, Near Indir...           True
# 295                           They have no ration card          False
# 314                                               None          False
# 318                                               None          False
# 320                                               none          False
# 321                     Educated abt the govt schemes.          False
# 326                                       Agriculture            True
# 335  Driver in Uber. We have money from my earnings...          False
# 349                                      Not required           False
# 383                      Media work and still working.          False
# 387  Has no information about schemes , doesn't hav...          False
# 394                               Currently unemployed          False
# 402  Private employee. Not going to work because of...          False
# 406  private company me kaam krte hai abhi chutti m...          False
# 408  They are well to do and ensure that they take ...          False
# 415  Is a Zamindar, has no challenges and is infact...          False
# 423                                                 NA           True
# 424            No government facilities have been used          False
# 427                                              none.          False
# 458  Ration has given that also with additional cos...           True
# 484                                                  -          False
# 501  THIS PERSON IS TAXI DRIVER AND HE IS NOW UNEMP...          False
# 543                                                N/A          False
# 566  They not aware of govt benefits as migrant lab...           True
# 574  Soaps were distributed in the area but they co...          False
# 581                                        No comments          False
# 595  His family was fine and had all the required e...          False
# 597  works in pharma company. Work is on as a part ...           True
# 614  House owner and his family member are not regi...           True
# 626                                                  -           True
# 639  Doesn't avail any of the above schemes, doesn'...          False
# 642                                                 NA          False
# 644  Sanjay Saroj\nLaxminagar, Plot No. 108, Naroda...          False
# 651                                                 NA          False
# 654                                                 NA          False
# 656  Need to process Ration card as Mukeshbhai Kana...          False
# 658                                 No help from Govt.           True
# 669                                             Barbar           True
# 698  No benefits registered . Person is auto driver...           True
# 709                      Services need to be provided.          False
# 724  The speaker was reluctant to share information...          False
# 725                    Employment status- didn't share          False
# 731                                                 Na           True
# 732                                no any suggestions            True
# 733                                               none          False
# 751  He was employed in a district hospital and did...          False
# 755                                                 NA          False
# 766                                                  .          False
# 781  private account, have ration card but the gove...           True
#
#                                    comments_additional
# 1    He works in a private job in Jaipur but curren...
# 3    ola me driver the abhi berojgar hai. future ko...
# 7                                                   NA
# 23                                                  NA
# 24   bijli ka chota mota kaam krte the lock down ke...
# 65                                         No comments
# 73   More information regarding essentials in govan...
# 75                                         No comments
# 79                                         No comments
# 92                                                 Nil
# 93   Need help: Sujat Ali, Family of 5 in Sanjay Ga...
# 94   Informed him that i will forward his number to...
# 100                                                 NA
# 102                                                 NA
# 107                                F/o Jandhan account
# 119                                                 NA
# 157  Vishal Medhe, working in Pune now in Baramati ...
# 163  As he is the only working member in a family o...
# 180                                        seemed fine
# 206  They live in government quarters and hence are...
# 208                                                 ..
# 210  He made a note of the information provided and...
# 216                                                 NA
# 223  Busy therefore disconnected the call...incompl...
# 225  No ration being given at ration shops without ...
# 237  Can survive this lockdown till April end, will...
# 261  Tushar Patel,\n303, Sitapalace Apartment, Gane...
# 262  Although i provided him with helpline numbers ...
# 268  Rima and her husband were informed about servi...
# 293  Kalpesh Chakravati\n13, Meeranagar, Near Indir...
# 295  వారికి రేషన్ కార్డు లేదుfood kii  ఇబ్బంది  పడు...
# 314  The stakeholder mentioned that he and his fami...
# 318  The stakeholder was hesitant to share any info...
# 320  the stakeholder (Mr Raju) is still in Bangalor...
# 321                                                 na
# 326  He needs a ration supply.\nLocated in Uttar Pr...
# 335  We are middle class family. We cant live but w...
# 349                                   Financially good
# 383  He does media work and still working. No emerg...
# 387  Has no information about schemes , doesn't hav...
# 394                                               None
# 402                                               none
# 406                         koi samsya fihlal nahi hai
# 408                                                 NA
# 415                                                 NA
# 423                                                 NA
# 424                                               Safe
# 427                                               none
# 458  His brother-in-law has committed suicide.\nPol...
# 484  Wasn't able to ask about the 'public services'...
# 501                                                 NA
# 543  The person was safe and had everything require...
# 566  May be needed to follow up them. I have given ...
# 574        The receiver had information about schemes.
# 581  Person is unemployed for the last 2 years, how...
# 595  His own family is fine in their village. Howev...
# 597  Need help in getting ration in the area khana ...
# 614  The house owner is not interested in talking b...
# 626  Need to share info about food supply helpline....
# 639  I forgot to ask about the employment status. S...
# 642                                                 NA
# 644  Sanjay Saroj\nLaxminagar, Plot No. 108, Naroda...
# 651  I didn't ask about the Public schemes since th...
# 654                                                 NA
# 656  \nNeed to process Ration card as Mukeshbhai Ka...
# 658  NazirHusen Anwar Shaikh\nMandwi Rajturachi ni ...
# 669                                          Need food
# 698  Numbers have been shared with the family and s...
# 709  other people need help. I was a government sch...
# 724  The speaker was reluctant to share information...
# 725  No emergency situation, very reluctant to shar...
# 731                                                 Na
# 732                                       no comments
# 733                                               none
# 751  He was employed in a district hospital and did...
# 755  The person suspected my credibility and said h...
# 766                                                  .
# 781                                                  .

# %%
# bpl and general ration
survey[(survey['eligible_bpl_ration']==True) & (survey['eligible_general_ration']==True)]
# Out:
#                            ID        time_created       time_modified  \
# 101  5e8dab58f0d65d001aac6a03 2020-04-08 16:15:00 2020-04-08 16:15:00
# 106  5e8daa92f0d65d001aac69ee 2020-04-08 16:12:00 2020-04-08 16:12:00
# 112  5e8da990f0d65d001aac6875 2020-04-08 16:08:00 2020-04-08 16:08:00
# 172  5e8d9996f0d65d001aac5f88 2020-04-08 14:59:00 2020-04-08 14:59:00
# 392  5e8c6e45f0d65d001aac46c2 2020-04-07 17:42:00 2020-04-07 17:42:00
# 458  5e8c6030f0d65d001aac417f 2020-04-07 16:42:00 2020-04-07 16:42:00
# 482  5e8c5833f0d65d001aac4037 2020-04-07 16:08:00 2020-04-07 16:08:00
# 491  5e8c55ccf0d65d001aac3e9d 2020-04-07 15:58:00 2020-04-07 15:58:00
# 494  5e8c54e3f0d65d001aac3e6b 2020-04-07 15:54:00 2020-04-07 15:54:00
# 495  5e8c54e2f0d65d001aac3e68 2020-04-07 15:54:00 2020-04-07 15:54:00
# 542  5e8c4b91f0d65d001aac3927 2020-04-07 15:14:00 2020-04-07 15:14:00
# 561  5e8c46acf0d65d001aac34c0 2020-04-07 14:53:00 2020-04-07 14:53:00
# 680  5e8c02d9f0d65d001aac0a53 2020-04-07 10:04:00 2020-04-07 10:04:00
# 745  5e8b1b0ff0d65d001aabf879 2020-04-06 17:35:00 2020-04-06 17:35:00
#
#                                 surveyer number_id  call_connected  \
# 101            indusActionStaffVolunteer    754674            True
# 106  solveNinjaReapBenefitStaffVolunteer    812495            True
# 112            indusActionStaffVolunteer    607727            True
# 172            indusActionStaffVolunteer    905897            True
# 392            indusActionStaffVolunteer       NaN            True
# 458            indusActionStaffVolunteer    915304            True
# 482            indusActionStaffVolunteer    615981            True
# 491            indusActionStaffVolunteer    662950            True
# 494            indusActionStaffVolunteer    619473            True
# 495            indusActionStaffVolunteer    619473            True
# 542            indusActionStaffVolunteer    994950            True
# 561            indusActionStaffVolunteer    837390            True
# 680            indusActionStaffVolunteer    664301            True
# 745            indusActionStaffVolunteer    199927            True
#
#     availability           state           sub_district    end_call_status  \
# 101         True       Rajasthan          Shastri Nagar           callDone
# 106         True    Chhattisgarh                Sakhara  callAgainFollowUp
# 112         True       Rajasthan                 312024           callDone
# 172         True     Maharashtra                  Wakad           callDone
# 392         True       Rajasthan                    N A           callDone
# 458         True     Maharashtra  Sanatacruz, Bus Stand  callAgainFollowUp
# 482         True   Uttar Pradesh               Sandauli           callDone
# 491         True       Rajasthan               Bandikui           callDone
# 494         True       Telangana                E C I L           callDone
# 495         True       Telangana                E C I L           callDone
# 542         True       Rajasthan                 Bhenad           callDone
# 561         True     Maharashtra                  Kurla           callDone
# 680         True           Bihar        Darangasighvara           callDone
# 745         True  Madhya Pradesh                    N A           callDone
#
#         district need_meds                                    comments_health  \
# 101       Jaipur     False                                                 NA
# 106        Balod     False                                                Nil
# 112      Udaipur     False                                                 NA
# 172         Pune     False                                           All fine
# 392      Bikaner     False                                                 NA
# 458  Mumbai City     False                                                 No
# 482    Barabanki     False                                                  -
# 491        Dausa     False                             All good , no problems
# 494    Hyderabad     False      gave them emergency numbers to get assistance
# 495    Hyderabad     False      gave them emergency numbers to get assistance
# 542       Jaipur     False                              No problems right now
# 561  Mumbai City     False                                               Fine
# 680    Darbhanga      True  No hospital facility nearby hence they have di...
# 745       Bhopal     False                               Doing fine right now
#
#     have_food                                      comments_food  \
# 101     False                                                 NA
# 106     False  Only rice that also at the cost of 1 rs. And n...
# 112     False                    Will have problems after 10 day
# 172      True                                           All fine
# 392      True                                                 NA
# 458     False  No food to eat. No government food has been re...
# 482      True                                                  -
# 491     False                   All good, home is well furnished
# 494      True                 had ration card and had no problem
# 495      True                 had ration card and had no problem
# 542     False  For now i have food, but no visibility  beyond...
# 561      True                      Will take benefit of ration.
# 680     False                                                 NA
# 745      True                                       Good for now
#
#     received_mgnrega received_pm_kisan received_ujjwala received_jan_dhan  \
# 101            False             False            False             False
# 106            False             False            False             False
# 112            False             False            False             False
# 172            False             False            False             False
# 392             True             False            False             False
# 458            False             False            False             False
# 482            False             False            False              True
# 491             True              True             True              True
# 494            False             False            False             False
# 495            False             False            False             False
# 542            False             False            False             False
# 561            False             False            False             False
# 680            False             False            False             False
# 745            False             False            False             False
#
#     received_old_age_widow received_registered_labor received_free_ration  \
# 101                  False                     False                False
# 106                  False                     False                 True
# 112                  False                     False                False
# 172                  False                     False                False
# 392                  False                     False                 True
# 458                  False                     False                False
# 482                  False                     False                False
# 491                  False                      True                 True
# 494                  False                     False                 True
# 495                  False                     False                 True
# 542                  False                     False                False
# 561                  False                     False                False
# 680                  False                     False                False
# 745                  False                     False                 True
#
#     received_not_eligible received_none eligible_mgnrega eligible_pm_kisan  \
# 101                 False          True             True             False
# 106                 False         False             True             False
# 112                 False          True            False             False
# 172                 False          True            False             False
# 392                 False         False             True             False
# 458                 False          True             True             False
# 482                 False         False            False              True
# 491                 False         False             True             False
# 494                 False         False            False              True
# 495                 False         False            False              True
# 542                 False          True             True             False
# 561                 False          True            False             False
# 680                 False          True            False             False
# 745                 False         False            False             False
#
#     eligible_ujjwala eligible_jan_dhan eligible_old_age_widow  \
# 101             True              True                  False
# 106             True             False                  False
# 112            False              True                  False
# 172            False             False                   True
# 392            False             False                  False
# 458            False             False                  False
# 482             True              True                  False
# 491             True              True                  False
# 494            False             False                  False
# 495            False             False                  False
# 542             True              True                  False
# 561            False             False                   True
# 680            False             False                   True
# 745            False             False                  False
#
#     eligible_registered_labor eligible_bpl_ration eligible_general_ration  \
# 101                     False                True                    True
# 106                     False                True                    True
# 112                      True                True                    True
# 172                     False                True                    True
# 392                     False                True                    True
# 458                     False                True                    True
# 482                     False                True                    True
# 491                      True                True                    True
# 494                     False                True                    True
# 495                     False                True                    True
# 542                     False                True                    True
# 561                     False                True                    True
# 680                     False                True                    True
# 745                     False                True                    True
#
#     eligible_none       employment_status  \
# 101         False  employedInformalSector
# 106         False  employedInformalSector
# 112         False  employedInformalSector
# 172         False    employedFormalSector
# 392         False  unemployedPostLockdown
# 458          True  employedInformalSector
# 482         False              unemployed
# 491         False  unemployedPostLockdown
# 494         False  employedInformalSector
# 495         False  employedInformalSector
# 542         False  unemployedPostLockdown
# 561         False  employedInformalSector
# 680         False  unemployedPostLockdown
# 745         False  unemployedPostLockdown
#
#                                      comments_benefits need_to_revert  \
# 101                                                 NA          False
# 106                                                Nil           True
# 112                                                 NA           True
# 172                                               None          False
# 392  He is a farmer but doesn't have PM Kisan accou...          False
# 458  Ration has given that also with additional cos...           True
# 482                                             Farmer          False
# 491                                                 NA          False
# 494                       was aware about his benefits          False
# 495                       was aware about his benefits          False
# 542  Has registered for all services but does not g...           True
# 561                    Not received any benefits yet.           False
# 680                                                 NA          False
# 745  Doing fine right now but will find it difficul...          False
#
#                                    comments_additional
# 101  Daily wage worker, did not know much about ser...
# 106  The caller was aware of the MGNREGA scheme but...
# 112                                                 NA
# 172  Rahul Pawar, was living in Wakad, Pune but is ...
# 392  He is a farmer but doesn't have PM Kisan accou...
# 458  His brother-in-law has committed suicide.\nPol...
# 482                                                  -
# 491                                                 NA
# 494  the family was of 2, wife and husband had no p...
# 495  the family was of 2, wife and husband had no p...
# 542  He has all the cards, but does not know why he...
# 561                      Was not aware of the schemes.
# 680  The family is still waiting in hopes of the go...
# 745                                                 NA

# %%
# overall eligibility vs scheme wise eligibility doesn't match
survey[(survey['eligible_none']==True) & (survey[['received_mgnrega', 'received_pm_kisan',
       'received_ujjwala', 'received_jan_dhan', 'received_old_age_widow',
       'received_registered_labor', 'received_free_ration',
       'eligible_mgnrega', 'eligible_pm_kisan', 'eligible_ujjwala', 'eligible_jan_dhan',
       'eligible_old_age_widow', 'eligible_registered_labor',
       'eligible_bpl_ration', 'eligible_general_ration']].isin([True]).any(axis=1))]
# Out:
#                            ID        time_created       time_modified  \
# 107  5e8daa76f0d65d001aac69eb 2020-04-08 16:11:00 2020-04-08 16:11:00
# 119  5e8da7e4f0d65d001aac6853 2020-04-08 16:01:00 2020-04-08 16:01:00
# 295  5e8d5bd5f0d65d001aac537f 2020-04-08 10:36:00 2020-04-08 10:36:00
# 320  5e8c8350f0d65d001aac4d34 2020-04-07 19:12:00 2020-04-07 19:12:00
# 321  5e8c8229f0d65d001aac4d30 2020-04-07 19:07:00 2020-04-07 19:07:00
# 326  5e8c80bbf0d65d001aac4d1c 2020-04-07 19:01:00 2020-04-07 19:01:00
# 458  5e8c6030f0d65d001aac417f 2020-04-07 16:42:00 2020-04-07 16:42:00
# 566  5e8c4594f0d65d001aac32b3 2020-04-07 14:49:00 2020-04-07 14:49:00
# 784  5e8b10f4f0d65d001aabf4d7 2020-04-06 16:52:00 2020-04-06 16:52:00
#
#                       surveyer number_id  call_connected availability  \
# 107  indusActionStaffVolunteer    659303            True         True
# 119  indusActionStaffVolunteer    889293            True         True
# 295  indusActionStaffVolunteer    501318            True         True
# 320  indusActionStaffVolunteer    836660            True         True
# 321  indusActionStaffVolunteer    403316            True         True
# 326  indusActionStaffVolunteer    344830            True         True
# 458  indusActionStaffVolunteer    915304            True         True
# 566  indusActionStaffVolunteer    354182            True         True
# 784  indusActionStaffVolunteer    919805            True         True
#
#               state                 sub_district    end_call_status  \
# 107  Madhya Pradesh                      Thencha  callAgainFollowUp
# 119       Rajasthan                Shastri Nagar           callDone
# 295       Telangana        Uppaguda N R I Colony  callAgainFollowUp
# 320       Karnataka                    Shakangar           callDone
# 321   Uttar Pradesh                     Harnatha           callDone
# 326   Uttar Pradesh                   Goaltowli.           callDone
# 458     Maharashtra        Sanatacruz, Bus Stand  callAgainFollowUp
# 566       Telangana  Yellareddyguda, Malkajigiri           callDone
# 784         Haryana                    Faridabad           callDone
#
#             district need_meds  \
# 107          Barwani      True
# 119           Jaipur     False
# 295       Sangareddy     False
# 320  Bangalore Rural     False
# 321           Amethi     False
# 326     Kanpur Dehat     False
# 458      Mumbai City     False
# 566        Hyderabad     False
# 784        Faridabad     False
#
#                                        comments_health have_food  \
# 107  A kid in the house has TB. Will have to check ...      True
# 119                                                 NA     False
# 295                                           ఏం లేదు       True
# 320                                               none     False
# 321                                            No need      True
# 326                                   No medical need.     False
# 458                                                 No     False
# 566  Using medicine which is available near by medi...     False
# 784     Has Stocked up on all the necessary medicines.      True
#
#                                          comments_food received_mgnrega  \
# 107  Has food for now. Has ration card too. Gave hi...            False
# 119                                                 NA            False
# 295                                            ఎం లేదు            False
# 320                                               none            False
# 321                               Bought their ration             False
# 326                                      Needs ration.            False
# 458  No food to eat. No government food has been re...            False
# 566  They were labour construction worker, migrated...            False
# 784                  All the essential shops are open             False
#
#     received_pm_kisan received_ujjwala received_jan_dhan  \
# 107             False            False             False
# 119             False             True              True
# 295             False            False             False
# 320             False             True             False
# 321             False             True              True
# 326             False             True              True
# 458             False            False             False
# 566             False            False             False
# 784             False            False             False
#
#     received_old_age_widow received_registered_labor received_free_ration  \
# 107                  False                     False                False
# 119                  False                     False                 True
# 295                  False                     False                 True
# 320                  False                     False                False
# 321                  False                     False                 True
# 326                  False                     False                False
# 458                  False                     False                False
# 566                  False                      True                 True
# 784                  False                     False                False
#
#     received_not_eligible received_none eligible_mgnrega eligible_pm_kisan  \
# 107                 False          True            False             False
# 119                 False         False            False             False
# 295                 False         False            False             False
# 320                 False          True            False             False
# 321                 False         False            False             False
# 326                 False         False            False             False
# 458                 False          True             True             False
# 566                 False         False            False             False
# 784                  True          True            False             False
#
#     eligible_ujjwala eligible_jan_dhan eligible_old_age_widow  \
# 107             True             False                  False
# 119            False             False                  False
# 295            False             False                  False
# 320            False             False                  False
# 321            False             False                  False
# 326            False              True                  False
# 458            False             False                  False
# 566            False             False                  False
# 784            False             False                  False
#
#     eligible_registered_labor eligible_bpl_ration eligible_general_ration  \
# 107                     False               False                    True
# 119                     False               False                   False
# 295                     False               False                   False
# 320                     False               False                   False
# 321                     False               False                   False
# 326                     False                True                   False
# 458                     False                True                    True
# 566                     False               False                   False
# 784                     False               False                    True
#
#     eligible_none       employment_status  \
# 107          True  unemployedPostLockdown
# 119          True    employedFormalSector
# 295          True              unemployed
# 320          True  unemployedPostLockdown
# 321          True  employedInformalSector
# 326          True  employedInformalSector
# 458          True  employedInformalSector
# 566          True  employedInformalSector
# 784          True  employedInformalSector
#
#                                      comments_benefits need_to_revert  \
# 107                                                NA            True
# 119                                                 NA          False
# 295                           They have no ration card          False
# 320                                               none          False
# 321                     Educated abt the govt schemes.          False
# 326                                       Agriculture            True
# 458  Ration has given that also with additional cos...           True
# 566  They not aware of govt benefits as migrant lab...           True
# 784          Haven't opted for any government schemes.          False
#
#                                    comments_additional
# 107                                F/o Jandhan account
# 119                                                 NA
# 295  వారికి రేషన్ కార్డు లేదుfood kii  ఇబ్బంది  పడు...
# 320  the stakeholder (Mr Raju) is still in Bangalor...
# 321                                                 na
# 326  He needs a ration supply.\nLocated in Uttar Pr...
# 458  His brother-in-law has committed suicide.\nPol...
# 566  May be needed to follow up them. I have given ...
# 784  Well Informed about the current situation and ...

# %%
survey[pd.isnull(survey[survey.columns.difference(['number_id', 'comments_additional','comments_food', 
                                                   'comments_health', 'sub_district', 'comments_benefits'])]).any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [ID, time_created, time_modified, surveyer, number_id, call_connected, availability, state, sub_district, end_call_status, district, need_meds, comments_health, have_food, comments_food, received_mgnrega, received_pm_kisan, received_ujjwala, received_jan_dhan, received_old_age_widow, received_registered_labor, received_free_ration, received_not_eligible, received_none, eligible_mgnrega, eligible_pm_kisan, eligible_ujjwala, eligible_jan_dhan, eligible_old_age_widow, eligible_registered_labor, eligible_bpl_ration, eligible_general_ration, eligible_none, employment_status, comments_benefits, need_to_revert, comments_additional]
# Index: []

# %%
len(survey['time_created'].dt.strftime("%d/%m/%Y").unique())
# Out:
# 3

# %% [markdown]
# ## Data aggregation

# %%
def get_dashboard_row(df, agg_level, state, district):
    
    date = df['time_created'].max().strftime("%d/%m/%Y")
    num_days = len(df['time_created'].dt.strftime("%d/%m/%Y").unique())
    num_surveyed = len(df)
    
    num_unemployed = len(df[df['employment_status'] == 'unemployed'])
    perc_unemployed = num_unemployed / num_surveyed
    
    num_unemployed_post_lockdown = len(df[df['employment_status'] =='unemployedPostLockdown'])
    perc_unemployed_post_lockdown = num_unemployed_post_lockdown / num_surveyed
    
    num_eligible_jan_dhan = len(df[df['eligible_jan_dhan'] == True])
    perc_eligible_jan_dhan = num_eligible_jan_dhan / num_surveyed
    
    num_need_med = len(df[df['need_meds'] == True])
    perc_need_med = num_need_med / num_surveyed
    
    num_need_food = len(df[df['have_food'] == False])
    perc_need_food = num_need_food / num_surveyed

    perc_received_no_benefit = -999
    perc_received_mgnrega = -999
    perc_received_pm_kisan = -999
    perc_received_ujjwala = -999
    perc_received_jan_dhan = -999
    perc_received_old_age_widow_disability = -999
    perc_received_registered_labor = -999
    perc_received_free_ration = -999

    num_eligible_atleast_one = len(df[df['eligible_none'] == False])
    num_received_no_benefit = len(df[(df['received_none'] == True) & (df['eligible_none'] == False)])
    if (num_eligible_atleast_one > 0):
        perc_received_no_benefit = num_received_no_benefit / num_eligible_atleast_one

    num_eligible_mgnrega = len(df[df['eligible_mgnrega'] == True])
    num_received_mgnrega = len(df[df['received_mgnrega'] == True])
    if (num_eligible_mgnrega > 0):
        perc_received_mgnrega = num_received_mgnrega / num_eligible_mgnrega

    num_eligible_pm_kisan = len(df[df['eligible_pm_kisan'] == True])
    num_received_pm_kisan = len(df[df['received_pm_kisan'] == True])
    if (num_eligible_pm_kisan > 0):
        perc_received_pm_kisan = num_received_pm_kisan / num_eligible_pm_kisan

    num_eligible_ujjwala = len(df[df['eligible_ujjwala'] == True])
    num_received_ujjwala = len(df[df['received_ujjwala'] == True])
    if (num_eligible_ujjwala > 0):
        perc_received_ujjwala = num_received_ujjwala / num_eligible_ujjwala

    num_received_jan_dhan = len(df[df['received_jan_dhan'] == True])
    if (num_eligible_jan_dhan > 0):
        perc_received_jan_dhan = num_received_jan_dhan / num_eligible_jan_dhan

    num_eligible_old_age_widow_disability = len(df[df['eligible_old_age_widow'] == True])
    num_received_old_age_widow_disability = len(df[df['received_old_age_widow'] == True])
    if (num_eligible_old_age_widow_disability > 0):
        perc_received_old_age_widow_disability = num_received_old_age_widow_disability / num_eligible_old_age_widow_disability
    
    num_eligible_registered_labor = len(df[df['eligible_registered_labor'] == True])
    num_received_registered_labor = len(df[df['received_registered_labor'] == True])
    if (num_eligible_registered_labor > 0):
        perc_received_registered_labor = num_received_registered_labor / num_eligible_registered_labor

    num_eligible_free_ration = len(df[(df['eligible_bpl_ration'] == True) | (df['eligible_general_ration'] == True)])
    num_received_free_ration = len(df[df['received_free_ration'] == True])
    if (num_eligible_free_ration > 0):
        perc_received_free_ration = num_received_free_ration / num_eligible_free_ration

    return [agg_level, state, district, date, num_days, num_surveyed, 
            num_unemployed, perc_unemployed, num_unemployed_post_lockdown, perc_unemployed_post_lockdown,  
            num_eligible_jan_dhan, perc_eligible_jan_dhan, num_need_med, perc_need_med, 
            num_need_food, perc_need_food, 
            num_eligible_atleast_one, num_received_no_benefit, perc_received_no_benefit, 
            num_eligible_mgnrega, num_received_mgnrega, perc_received_mgnrega, 
            num_eligible_pm_kisan, num_received_pm_kisan, perc_received_pm_kisan,
            num_eligible_ujjwala, num_received_ujjwala, perc_received_ujjwala,
            num_received_jan_dhan, perc_received_jan_dhan,
            num_eligible_old_age_widow_disability, num_received_old_age_widow_disability, 
            perc_received_old_age_widow_disability,
            num_eligible_registered_labor, num_received_registered_labor, perc_received_registered_labor,
            num_eligible_free_ration, num_received_free_ration, perc_received_free_ration]

# %%
column_names = ['agg_level', 'state', 'district', 'date', 'num_days', 'num_surveyed', 
                'num_unemployed', 'perc_unemplyed', 'num_unemployed_post_lockdown', 'perc_unemployed_post_lockdown',
                'num_eligible_jan_dhan', 'perc_eligible_jan_dhan', 'num_need_med', 'perc_need_med', 
                'num_need_food', 'perc_need_food', 
                'num_eligible_atleast_one', 'num_received_no_benefit', 'perc_received_no_benefit', 
                'num_eligible_mgnrega', 'num_received_mgnrega', 'perc_received_mgnrega', 
                'num_eligible_pm_kisan', 'num_received_pm_kisan', 'perc_received_pm_kisan',
                'num_eligible_ujjwala', 'num_received_ujjwala', 'perc_received_ujjwala',
                'num_received_jan_dhan', 'perc_received_jan_dhan',
                'num_eligible_old_age_widow_disability', 'num_received_old_age_widow_disability', 
                'perc_received_old_age_widow_disability',
                'num_eligible_registered_labor', 'num_received_registered_labor', 'perc_received_registered_labor',
                'num_eligible_free_ration', 'num_received_free_ration', 'perc_received_free_ration']
dashboard = pd.DataFrame(columns = column_names)

# %%
states = survey['state'].unique().tolist()
states = [state for state in states if str(state) != 'nan']

# %%
for state in states:
    state_df = survey[survey['state'] == state]
    dashboard = dashboard.append(pd.Series(get_dashboard_row(state_df, 'State', state, -999),
                                           index=dashboard.columns ), ignore_index=True)
    districts = state_df['district'].unique().tolist()
    districts = [district for district in districts if str(district) != 'nan']
    for district in districts:
        dist_df = state_df[state_df['district'] == district]
        dashboard = dashboard.append(pd.Series(get_dashboard_row(dist_df, 'District', state, district),
                                               index=dashboard.columns ), ignore_index=True)

# %%
dashboard.to_csv('data/dashboard_08_04.csv', index=False)
